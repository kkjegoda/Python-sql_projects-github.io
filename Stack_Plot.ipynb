# %%
import matplotlib.pyplot as plt
days =[1,2,3,4,5,6,7]
Nop1=[5,10,20,30,35,60,80]
Nop2=[10,20,30,25,40,50,90]
Nop3=[40,40,50,60,70,90,100]
plt.stackplot(days,Nop1,Nop2,Nop3,colors=["pink","red","blue"],labels=["week1","week2","week3"])
plt.legend()
plt.show()
