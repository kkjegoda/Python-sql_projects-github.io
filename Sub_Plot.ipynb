# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[23,34,56,78,45]

plt.subplot(2,2,1)
plt.title("age")
plt.bar(x,y)

x=[5,6,7,8,9]
y=[89,78,30,49,29]
plt.subplot(2,2,2)
plt.title("weight")
plt.plot(x,y)
plt.suptitle("employee data")
plt.show()
